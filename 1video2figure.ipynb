# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt
import random
import copy

# %%
regular = '7.jpg'
Seven = cv2.imread(regular, cv2.IMREAD_COLOR)
plt.imshow(Seven)

# %%
plt.imshow(Seven[:, :, 0])

# %%
blue = 'Color_under_Blue.jpg'
A = cv2.imread(blue, 1)
print(len(A))
print(len(A[0][0]))
print(len(A[1]))
print(len(A[2]))
# Out:
# 538
# 3
# 674
# 674

# %%
plt.imshow(A[:, :, 0])

# %%
plt.imshow(A[:, :, 1])

# %%
plt.imshow(A[:, :, 2])

# %%
for i in range(538):
    for j in range(674):
        if A[i][j][0] < 48:
            A[i][j] = [0, 0, 255]
cv2.imwrite('slime_occupy.jpg', A)
plt.imshow(A)

# %%
B = A[:, :, 0]
C = 0
print(len(B), len(B[0]))
for i in range(538):
    for j in range(674):
        if(B[i][j] < 48):
            C += 1
print(C)
print(538*674)
print(C/(538*674))


# Blue： 48
# Out:
# 538 674
# 73401
# 362612
# 0.2024229755220456

# %%
print(A[1])
# Out:
# [ 41  43  44  46  54  65  74  76  78  81  84  86  87  88  89  90  90  90
#   90  91  91  91  91  91  92  92  92  92  93  94  96  96  97  95  93  92
#   92  92  91  90  89  87  85  84  82  81  80  79  80  81  83  82  81  80
#   80  80  79  80  80  81  81  80  79  78  78  78  78  78  78  78  78  79
#   78  78  78  78  78  79  80  80  78  78  77  76  76  76  76  77  79  78
#   77  77  77  77  78  78  78  77  76  75  74  72  71  71  72  71  70  71
#   74  75  75  75  73  73  73  73  73  73  74  75  73  75  77  79  80  82
#   85  88  91  92  93  94  94  95  96  97  98  98  99 100 100 100 100 100
#   98  97  97  96  95  93  92  91  93  88  85  85  83  79  77  78  76  75
#   73  73  74  74  72  71  70  70  70  70  70  69  69  70  70  69  68  67
#   66  66  66  66  66  66  66  65  65  65  65  65  66  65  63  63  63  64
#   65  67  64  64  65  64  63  63  63  64  66  65  64  63  64  64  64  63
#   62  64  65  65  63  63  64  66  65  64  64  63  61  60  60  59  60  60
# ...

# %%
print(A[2])
# Out:
# [ 39  43  45  48  55  67  76  79  78  80  84  86  87  88  88  89  90  90
#   90  91  91  91  91  92  92  92  92  92  93  94  95  96  97  94  92  91
#   91  91  90  89  87  85  84  84  85  84  81  79  80  81  82  82  81  80
#   80  80  80  81  81  81  81  80  79  79  78  77  76  77  78  79  79  79
#   77  78  78  79  79  79  79  79  76  76  77  77  76  76  75  75  78  77
#   77  77  77  77  78  79  78  78  76  75  73  71  70  69  69  69  69  70
#   72  73  73  72  73  72  72  72  72  73  73  74  74  75  77  79  80  82
#   85  88  89  92  93  93  91  92  95  99  98  98  99 100 100 100  99  99
#   98  96  94  93  91  91  90  91  90  85  82  82  80  77  75  75  75  74
#   73  73  73  73  72  71  71  70  69  69  69  70  71  71  72  71  69  67
#   66  65  64  64  63  64  64  65  66  66  67  67  66  66  64  63  63  64
#   65  65  66  65  64  64  64  64  63  62  65  65  65  64  63  63  64  64
#   64  65  65  65  64  64  64  65  65  64  64  63  62  60  60  59  60  61
# ...

# %%
file = '2021-03-31.mp4'
VideoCapture = cv2.VideoCapture(file)
, 5432809, 5537453, 6084306, 6402036, 6185345, 5772602, 6171960, 6266353, 7031523, 7645305, 6140079, 5242519, 5605729, 5817140, 6252861, 5848083, 5822592, 5963256, 6009386, 5886356, 5410223, 5752738, 6049653, 5744210, 5820100, 5743357, 5914743, 5549672, 5640319, 5694085, 5767280, 5476045, 5510656, 5705508, 5922228, 5731734, 6570364, 6720493, 5805263, 5324529, 5253241, 5658921, 5666899, 5330992, 5312709, 5592757, 5744345, 5391893, 5361579, 5682872, 5887015, 5462273, 5289059, 5649936, 5841716, 5362419, 5522487, 5814629, 5932515, 5415938, 5544589, 6043169, 6034945, 5634649, 5683669, 5908176, 5968667, 5430285, 5417176, 5660418, 5939425, 5772297, 5571023, 6153992, 5953979, 5574453, 5696873, 6358576, 7988021, 7987859, 6392778, 6646101, 5744522, 5417105, 5417986, 5632456, 5787839, 5571433, 5618161, 5904257, 5851741, 5456793, 5762973, 5740471]
f = np.hstack((f1, f2))
print(len(f))
# Out:
# 2229

# %%
plt.plot(f[180:240])

# %%
f_copy = copy.deepcopy(f)
random.shuffle(f_copy)
plt.plot(f_copy)

# %%
summ = []
summary = 0
for i in range(len(f_copy)):
    summary += f_copy[i]
    summ.append(summary)
plt.plot(summ)

# %%
cut = f[800:1000]
avg = sum(cut)/len(cut)
for i in range(len(cut)):
    cut[i] -= avg
#plt.plot(cut)
cft= np.fft.rfft(cut)
abcft = np.abs(cft)
freq = np.linspace(0, 30/2, len(cft))
plt.plot(freq, abcft)
plt.title('Slice Fourier Transform')
print(len(cft))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-bf851d693b5e> in <module>
#       1 cut = f[800:1000]
# ----> 2 avg = sum(cut)/len(cut)
#       3 for i in range(len(cut)):
#       4     cut[i] -= avg
#       5 #plt.plot(cut)
#
# TypeError: 'int' object is not callable

# %%
plt.figure(figsize = (200,10))
plt.plot(f)
plt.show()

# %%
average = sum(f)/len(f)
for i in range(len(f)):
    f[i] -= average
fourier_transform = np.fft.rfft(f)
print(fourier_transform)
# Out:
# [-4.00000000e+00+0.00000000e+00j -6.97775142e+08+5.97322967e+08j
#  -6.21769005e+07+8.37706458e+08j ...  2.80739875e+06+2.65903315e+07j
#  -1.26095090e+07-1.19149083e+07j  1.53994191e+07-1.09841931e+07j]

# %%
abs_fourier_transform = np.abs(fourier_transform)
print(abs_fourier_transform)
frequency = np.linspace(0, sr/2, len(fourier_transform))
# Out:
# [4.00000000e+00 9.18523204e+08 8.40010760e+08 ... 2.67381229e+07
#  1.73483359e+07 1.89154595e+07]

# %%
#sr
frequency = np.linspace(0, sr/2, len(fourier_transform))
plt.plot(frequency, abs_fourier_transform)
plt.title('Fourier Transform')
print(len(fourier_transform))
plt.show()
# Out:
# 1115

# %% [markdown]
# # Begin

# %%
print(2448*3264)
print(2448*3264*2231)
# Out:
# 7990272
# 17826296832

# %%
videoCapture = cv2.VideoCapture('2021-03-31.mp4')
videoCapture0 = cv2.VideoCapture('2021-03-31.mp4')
# num of z: 2231
#pixel:2448*3264
i=0
sum_dif = 0
space = []
diff = []

# %%
ret0, frame0 = videoCapture0.read()
for m in range(600):
    dif = 0
    ret1, frame1 = videoCapture.read() #start from frame0
    ret2, frame2 = videoCapture0.read()#start from frame1
    f1 = np.array(frame1)
    f1 = np.squeeze(f1)
    f2 = np.array(frame2)
    f2 = np.squeeze(f2)
    dif = 0
    for i in range(2448):
        for j in range(3264):
                if ((f1[i][j][0] != f2[i][j][0]) or (f1[i][j][1] != f2[i][j][1]) or (f1[i][j][2] != f2[i][j][2])):
                    dif +=1
    sum_dif += dif
    space.append(sum_dif)
    diff.append(dif)

# %%
print(space)
print(diff)
# Out:
# [7987582, 13141958, 18963781, 25024162, 31619580, 37515102, 43433083, 49655525, 56140613, 62114644, 68098542, 74313352, 80614496, 86556032, 92366573, 98486083, 104969201, 110951804, 116889636, 123036467, 129206911, 135102568, 140961621, 147153905, 153767721, 159622647, 165417905, 171493005, 177743301, 184134286, 190120760, 196403097, 202786153, 208685927, 214619151, 220667226, 227208295, 234456415, 241776635, 249112430, 256432646, 262556478, 268581299, 274859096, 280957760, 287072366, 293313525, 299568950, 306040968, 312413547, 318127769, 324226934, 330205660, 335829807, 341418702, 347451064, 353579189, 359688859, 365728915, 371770547, 377830360, 383537000, 389222900, 395321823, 401474291, 407216595, 413285476, 419451852, 426097144, 432489245, 438085011, 443974531, 449896385, 455528217, 461159763, 467076414, 473039372, 478668088, 484434081, 490332587, 496299716, 502297661, 508002887, 513930447, 519925273, 525524150, 531152576, 537111462, 543009913, 548466755, 554574878, 560859741, 56
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(space)

# %%
plt.plot(diff)

# %%
plt.plot(diff[:200])

# %%
plt.plot(diff[0:50])

# %%
# while True:
#     ret, frame = videoCapture.read()
#     if ret is False:
#         break
#     i += 1
# print(i)

# %%
ret1, frame1 = videoCapture.read()
ret2, frame2 = videoCapture.read()
print(frame2.shape)
# Out:
# (2448, 3264, 3)

# %%
print(len(frame1))
print(frame1)
#len(frame1) = 2248
# c1 = []
# c1 = f1[0]
# print(c1)
# print(len(c1))
f1 = np.array(frame1)
f1 = np.squeeze(f1)
print(f1)
# Out:
# 2448
# [[[27 44 20]
#   [25 42 18]
#   [26 44 18]
#   ...
#   [35 50 40]
#   [36 51 41]
#   [35 50 40]]
#
#  [[25 42 18]
#   [25 42 18]
#   [25 43 17]
#   ...
#   [35 50 40]
#   [36 51 41]
#   [36 51 41]]
#
#  [[23 44 17]
#   [23 44 17]
#   [23 44 17]
#   ...
#   [36 51 42]
#   [36 51 41]
#   [35 50 40]]
#
#  ...
#
#  [[26 47 37]
#   [25 46 36]
#   [23 44 34]
#   ...
#   [39 54 52]
#   [40 55 53]
#   [40 55 53]]
#
#  [[25 48 37]
#   [23 46 35]
#   [22 45 35]
#   ...
#   [38 53 51]
#   [38 53 51]
#   [38 53 51]]
#
#  [[26 49 38]
#   [25 48 37]
#   [23 46 36]
#   ...
#   [36 51 49]
#   [36 51 49]
#   [36 51 49]]]
# [[[27 44 20]
#   [25 42 18]
#   [26 44 18]
#   ...
#   [35 50 40]
#   [36 51 41]
#   [35 50 40]]
#
#  [[25 42 18]
#   [25 42 18]
#   [25 43 17]
#   ...
#   [35 50 40]
#   [36 51 41]
#   [36 51 41]]
#
#  [[23 44 17]
#   [23 44 17]
#   [23 44 17]
#   ...
#   [36 51 42]
#   [36 51 41]
#   [35 50 40]]
#
#  ...
#
#  [[26 47 37]
#   [25 46 36]
#   [23 44 34]
#   ...
# ...

# %%
f2 = np.array(frame2)
f2 = np.squeeze(f2)

# %%
dif = 0
for i in range(2448):
    for j in range(3264):
            if ((f1[i][j][0] != f2[i][j][0]) or (f1[i][j][1] != f2[i][j][1]) or (f1[i][j][2] != f2[i][j][2])):
                dif +=1

# %%
print(dif)
# Out:
# 6133060

# %%
import cv2
import numpy as np
import os

# %%
videoCapture1 = cv2.VideoCapture('2021-03-31.mp4')
videoCapture2 = cv2.VideoCapture('2021-03-31.mp4')
# num of z: 2231
#pixel:2448*3264

sum_dif1 = 0
space1 = []
diff1 = []

# %%
ret01, frame01 = videoCapture1.read()
for m in range(2231):
    dif = 0
    ret11, frame11 = videoCapture2.read() #start from frame0
    ret21, frame21 = videoCapture1.read()#start from frame1
    f1 = np.array(frame11)
    f1 = np.squeeze(f1)
    f2 = np.array(frame21)
    f2 = np.squeeze(f2)
    dif = 0
    for i in range(2448):
        for j in range(3264):
                if ((f1[i][j][0] != f2[i][j][0]) or (f1[i][j][1] != f2[i][j][1]) or (f1[i][j][2] != f2[i][j][2])):
                    dif +=1
    sum_dif1 += dif
    space1.append(sum_dif1)
    diff1.append(dif)

# %%
print(space1)
print(diff1)

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt

#pixels of a frame = 3264 * 2448
# def frame_counter(videoCapture):
#     frame_count = 0
#     while (ret0 == True):
#         ret0, frame0 = videoCapture.read()
#         if ret0 is False:
#             break
#         frame_count = frame_count + 1
#     return frame_count
# 1200:1400  1450:1650
def Width(frame0):
    return frame0.shape[1]

def Height(frame0):
    return frame0.shape[0]

def CutFrame(f, a, b):
    _f = f[a:b]
    return _f

def Difference(videoCapture1, videoCapture2, number_frame):
    sum_dif = 0
    overall_space = []
    diff = []
    for m in range(number_frame - 1):
        print(m , end='\r')  # show running
        dif = 0
        ret1, frame1 = videoCapture1.read()  # start from frame1
        ret2, frame2 = videoCapture2.read()  # start from frame0
        f1 = np.array(frame1)
        np.squeeze(f1)
        f2 = np.array(frame2)
        np.squeeze(f2)
        CutFrame(f1, 250, 750)
        CutFrame(f2, 250, 750)
        dif += np.sum(np.abs(f1 - f2))
        sum_dif += dif
        overall_space.append(sum_dif)
        diff.append(dif)
    plt.plot(diff, c='r')
    plt.plot(overall_space, c='b')
    plt.title('Summary & Differential of pixel changes')
    plt.show()

def show_slime_occupy(VideoCapture, number_frame, num_out):
    for i in range(number_frame//num_out):
        ret, frame = VideoCapture.read()
    for i in range(0, number_frame-number_frame//num_out-1, number_frame//num_out):
        for j in range(number_frame // num_out):
            ret, frame = VideoCapture.read()
        f = frame[975:1475]
        p = 0
        for x in range(500):
            for y in range(3264):
                if f[x][y][0] <= 48:#Changed here!!!
                    f[x][y] = [0, 0, 255]
                    p += 1
        print(i+number_frame//num_out, ':', p * 100 // (200 * 3264), '%')
        cv2.imwrite('%d'%i+'622slime_occupy.jpg', f)


def Capture_Yellow(videoCapture, number_frame):
    yellow_pixel = []
    for m in range(number_frame):
        n_yellow = 0
        ret, frame = videoCapture.read()
        f = np.array(frame)
        np.squeeze(f)
        f_c = CutFrame(f, 975, 1475)
        f_b = f_c[:,:,0]
        np.squeeze(f_b)
        flag = np.ones((500, 3264))
        flag *= 48
        f_b = np.mat(f_b)
        flag = np.mat(flag)
        f_b = f_b - flag
        f_b = np.array(f_b)
        # print(f_b.shape)
        # print(f_b[499][3263])
        for i in range(500):
            for j in range(3264):
                if f_b[i][j] < 0:
                    n_yellow += 1
        print(m, n_yellow)
        yellow_pixel.append(n_yellow)
    #print(yellow_pixel)
    diff = []
    for i in range(len(yellow_pixel)-1):
        dif = yellow_pixel[i+1] - yellow_pixel[i]
        diff.append(dif)

    # diff2 = []
    # for i in range(0,number_frame,30):
    #     dif = yellow_pixel[i] - yellow_pixel[i-30]
    #     diff2.append(dif)
    #
    # plt.plot(diff2, c='g')

    plt.plot(diff, c = 'r')
    plt.plot(yellow_pixel, c = 'b')
    plt.title('Summary & Differential of yellow pixel')
    plt.xlabel('Frames')
    plt.ylabel('Number of Pixels/%')
    plt.show()


def main():
    file = '2021-06-22.mp4'
    videoCapture0 = cv2.VideoCapture(file)
    videoCapture1 = cv2.VideoCapture(file)
    videoCapture2 = cv2.VideoCapture(file)
    videoCapture3 = cv2.VideoCapture(file)
    ret0, frame0 = videoCapture1.read()
    #width = Width(frame0)
    #height = Height(frame0) # Used to determine the range of the pixels we need
    #print('The width of the frame is ', width, '.  The height of the frame is ', height)
    number_frame = 4638   #frame_counter(videoCapture0)
    Capture_Yellow(videoCapture0, number_frame)
    # #Difference(videoCapture1, videoCapture2, number_frame)
    # show_slime_occupy(videoCapture3, 3, 2)
 
def five_min_volumn(dif):
    for i in range(len(dif)//10):
        pass



main()
# Out:
# 0 576351
# 1 569156
# 2 588675
# 3 581410
# 4 586764
# 5 578830
# 6 577467
# 7 578518
# 8 585260
# 9 583772
# 10 588592
# 11 586858
# 12 594836
# 13 588151
# 14 591631
# 15 591921
# 16 599261
# 17 595159
# 18 595821
# 19 595532
# 20 600745
# 21 597149
# 22 597290
# 23 600382
# 24 601919
# 25 601751
# 26 604233
# 27 603029
# 28 605541
# 29 607051
# 30 601979
# 31 602189
# 32 608355
# 33 604193
# 34 607922
# 35 613050
# 36 616439
# 37 610177
# 38 613976
# 39 610856
# 40 621177
# 41 608029
# 42 616819
# 43 612096
# 44 614673
# 45 610644
# 46 618537
# 47 615978
# 48 618359
# 49 618505
# 50 611719
# 51 609741
# 52 619132
# 53 619094
# 54 613333
# 55 609778
# 56 616335
# 57 612592
# 58 613429
# 59 614239
# 60 618151
# 61 616014
# 62 617278
# 63 609594
# 64 613258
# 65 612245
# 66 615899
# 67 615471
# 68 616859
# 69 614100
# 70 621835
# 71 621267
# 72 626885
# 73 617275
# 74 619798
# 75 624380
# 76 619646
# 77 616644
# 78 620507
# 79 630655
# 80 628114
# 81 621649
# 82 617919
# 83 629270
# ...
